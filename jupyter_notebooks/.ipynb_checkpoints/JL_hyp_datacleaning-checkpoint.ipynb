# %%
import pandas as pd

# %%
df = pd.read_csv('../Resources/frmgham2.csv')
df.head()
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1    2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 2    6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 3    6238    2    260.0   52  105.0   69.5         0      0.0  29.43
# 4    6238    2    237.0   58  108.0   66.0         0      0.0  28.50
#
#    DIABETES   ...     CVD  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  \
# 0         0   ...       1         0    8766    6438      6438     6438
# 1         0   ...       1         0    8766    6438      6438     6438
# 2         0   ...       0         0    8766    8766      8766     8766
# 3         0   ...       0         0    8766    8766      8766     8766
# 4         0   ...       0         0    8766    8766      8766     8766
#
#    TIMESTRK  TIMECVD  TIMEDTH  TIMEHYP
# 0      8766     6438     8766     8766
# 1      8766     6438     8766     8766
# ...

# %%
df.columns
# Out:
# Index(['RANDID', 'SEX', 'TOTCHOL', 'AGE', 'SYSBP', 'DIABP', 'CURSMOKE',
#        'CIGPDAY', 'BMI', 'DIABETES', 'BPMEDS', 'HEARTRTE', 'GLUCOSE', 'educ',
#        'PREVCHD', 'PREVAP', 'PREVMI', 'PREVSTRK', 'PREVHYP', 'TIME', 'PERIOD',
#        'HDLC', 'LDLC', 'DEATH', 'ANGINA', 'HOSPMI', 'MI_FCHD', 'ANYCHD',
#        'STROKE', 'CVD', 'HYPERTEN', 'TIMEAP', 'TIMEMI', 'TIMEMIFC', 'TIMECHD',
#        'TIMESTRK', 'TIMECVD', 'TIMEDTH', 'TIMEHYP'],
#       dtype='object')

# %%
#filter for Period = 1 and PREVHYP  = 0
HYP_df = df.loc[(df['PERIOD']==1) & (df['PREVHYP']==0)]
HYP_df
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0         2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 2         6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 5         9428    1    245.0   48  127.5   80.0         1     20.0  25.34
# 9        11252    2    285.0   46  130.0   84.0         1     23.0  23.10
# 15       12629    2    205.0   63  138.0   71.0         0      0.0  33.11
# 17       12806    2    313.0   45  100.0   71.0         1     20.0  21.68
# 26       16799    2    254.0   50  133.0   76.0         0      0.0  22.91
# 29       19304    2    247.0   43  131.0   88.0         0      0.0  27.64
# 35       24721    2    226.0   39  114.0   64.0         1      9.0  22.35
# 42       33555    2    291.0   46  112.0   78.0         1     20.0  23.38
# 43       34689    2    195.0   38  122.0   84.5         1      5.0  23.24
# 46       36459    1    195.0   41  139.0   88.0         0      0.0  26.88
# ...

# %%
#keep the columns we want
HYP_columns = ['RANDID', 'SEX', 'TOTCHOL', 'AGE', 'SYSBP', 'DIABP', 'CURSMOKE', 'CIGPDAY', 'BMI', 'DIABETES', 'BPMEDS',
              'HEARTRTE', 'GLUCOSE', 'PREVCHD', 'PREVAP', 'PREVSTRK', 'PREVHYP', 'TIME', 'PERIOD', 'DEATH', 'HYPERTEN',
              'TIMEHYP']
HYP_df = HYP_df[HYP_columns]
HYP_df
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0         2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 2         6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 5         9428    1    245.0   48  127.5   80.0         1     20.0  25.34
# 9        11252    2    285.0   46  130.0   84.0         1     23.0  23.10
# 15       12629    2    205.0   63  138.0   71.0         0      0.0  33.11
# 17       12806    2    313.0   45  100.0   71.0         1     20.0  21.68
# 26       16799    2    254.0   50  133.0   76.0         0      0.0  22.91
# 29       19304    2    247.0   43  131.0   88.0         0      0.0  27.64
# 35       24721    2    226.0   39  114.0   64.0         1      9.0  22.35
# 42       33555    2    291.0   46  112.0   78.0         1     20.0  23.38
# 43       34689    2    195.0   38  122.0   84.5         1      5.0  23.24
# 46       36459    1    195.0   41  139.0   88.0         0      0.0  26.88
# ...

# %%
#find nulls in our data
HYP_df.isnull().sum()
# Out:
# RANDID        0
# SEX           0
# TOTCHOL      35
# AGE           0
# SYSBP         0
# DIABP         0
# CURSMOKE      0
# CIGPDAY      23
# BMI          12
# DIABETES      0
# BPMEDS       35
# HEARTRTE      0
# GLUCOSE     280
# PREVCHD       0
# PREVAP        0
# PREVSTRK      0
# PREVHYP       0
# TIME          0
# PERIOD        0
# DEATH         0
# HYPERTEN      0
# TIMEHYP       0
# dtype: int64

# %%
HYP_final_df = HYP_df.dropna()
HYP_final_df
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0         2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 2         6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 5         9428    1    245.0   48  127.5   80.0         1     20.0  25.34
# 9        11252    2    285.0   46  130.0   84.0         1     23.0  23.10
# 15       12629    2    205.0   63  138.0   71.0         0      0.0  33.11
# 17       12806    2    313.0   45  100.0   71.0         1     20.0  21.68
# 26       16799    2    254.0   50  133.0   76.0         0      0.0  22.91
# 29       19304    2    247.0   43  131.0   88.0         0      0.0  27.64
# 42       33555    2    291.0   46  112.0   78.0         1     20.0  23.38
# 43       34689    2    195.0   38  122.0   84.5         1      5.0  23.24
# 46       36459    1    195.0   41  139.0   88.0         0      0.0  26.88
# 49       40435    2    190.0   42  108.0   70.5         1     30.0  21.59
# ...

# %%
HYP_final_df.to_csv('../Resources/HYP_final_data.csv', index=False)

# %%
HYP_g_df = HYP_df.drop(columns=['GLUCOSE'])
HYP_g_final_df = HYP_g_df.dropna()
HYP_g_final_df
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0         2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 2         6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 5         9428    1    245.0   48  127.5   80.0         1     20.0  25.34
# 9        11252    2    285.0   46  130.0   84.0         1     23.0  23.10
# 15       12629    2    205.0   63  138.0   71.0         0      0.0  33.11
# 17       12806    2    313.0   45  100.0   71.0         1     20.0  21.68
# 26       16799    2    254.0   50  133.0   76.0         0      0.0  22.91
# 29       19304    2    247.0   43  131.0   88.0         0      0.0  27.64
# 35       24721    2    226.0   39  114.0   64.0         1      9.0  22.35
# 42       33555    2    291.0   46  112.0   78.0         1     20.0  23.38
# 43       34689    2    195.0   38  122.0   84.5         1      5.0  23.24
# 46       36459    1    195.0   41  139.0   88.0         0      0.0  26.88
# ...

# %%
HYP_g_final_df.isnull().sum()
# Out:
# RANDID      0
# SEX         0
# TOTCHOL     0
# AGE         0
# SYSBP       0
# DIABP       0
# CURSMOKE    0
# CIGPDAY     0
# BMI         0
# DIABETES    0
# BPMEDS      0
# HEARTRTE    0
# PREVCHD     0
# PREVAP      0
# PREVSTRK    0
# PREVHYP     0
# TIME        0
# PERIOD      0
# DEATH       0
# HYPERTEN    0
# TIMEHYP     0
# dtype: int64

# %%
HYP_g_final_df.to_csv('../Resources/HYP_final_noglucose.csv', index=False)

# %%
HYP_3_df = df.loc[(df['PERIOD']==3) & (df['PREVHYP']==0)]
HYP_3_df
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 1         2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 4         6238    2    237.0   58  108.0   66.0         0      0.0  28.50
# 19       12806    2    320.0   57  110.0   46.0         1     30.0  22.02
# 28       16799    2    291.0   62  120.0   70.0         0      0.0  21.98
# 51       40435    2    226.0   54  126.0   75.0         1     40.0  21.59
# 54       43522    2      NaN   55  129.0   76.0         0      0.0  35.71
# 67       55965    2    298.0   72  109.0   60.0         0      0.0  26.20
# 80       68194    1    206.0   55  129.0   85.0         1     50.0  26.40
# 108      90705    2    216.0   54  100.0   75.0         1     16.0  29.82
# 111      94510    2    293.0   53  127.0   77.0         1      3.0  25.68
# 122      97026    2    206.0   61  112.0   80.0         0      0.0  21.96
# 128      98536    1    241.0   58  135.0   70.0         1     30.0  25.68
# ...

# %%
HYP_3_df.isnull().sum()
# Out:
# RANDID        0
# SEX           0
# TOTCHOL      79
# AGE           0
# SYSBP         0
# DIABP         0
# CURSMOKE      0
# CIGPDAY       5
# BMI           6
# DIABETES      0
# BPMEDS      171
# HEARTRTE      1
# GLUCOSE     205
# educ         32
# PREVCHD       0
# PREVAP        0
# PREVMI        0
# PREVSTRK      0
# PREVHYP       0
# TIME          0
# PERIOD        0
# HDLC         86
# LDLC         86
# DEATH         0
# ANGINA        0
# HOSPMI        0
# MI_FCHD       0
# ANYCHD        0
# STROKE        0
# CVD           0
# HYPERTEN      0
# TIMEAP        0
# TIMEMI        0
# TIMEMIFC      0
# TIMECHD       0
# TIMESTRK      0
# TIMECVD       0
# TIMEDTH       0
# TIMEHYP       0
# dtype: int64

# %%
#keep desired period 3 columns 
HYP_3_columns = ['RANDID', 'SEX', 'TOTCHOL', 'AGE', 'SYSBP', 'DIABP', 'CURSMOKE', 'CIGPDAY', 'BMI', 'DIABETES', 'BPMEDS',
              'HEARTRTE', 'GLUCOSE', 'PREVCHD', 'PREVAP', 'PREVSTRK', 'PREVHYP', 'TIME', 'PERIOD', 'DEATH', 'HYPERTEN',
              'TIMEHYP']
HYP_3_df = HYP_3_df[HYP_3_columns]
HYP_3_df_final = HYP_3_df.dropna()
HYP_3_df_final
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 4         6238    2    237.0   58  108.0   66.0         0      0.0  28.50
# 19       12806    2    320.0   57  110.0   46.0         1     30.0  22.02
# 51       40435    2    226.0   54  126.0   75.0         1     40.0  21.59
# 67       55965    2    298.0   72  109.0   60.0         0      0.0  26.20
# 80       68194    1    206.0   55  129.0   85.0         1     50.0  26.40
# 108      90705    2    216.0   54  100.0   75.0         1     16.0  29.82
# 111      94510    2    293.0   53  127.0   77.0         1      3.0  25.68
# 128      98536    1    241.0   58  135.0   70.0         1     30.0  25.68
# 138     112297    2    251.0   59  132.0   77.0         1     20.0  19.30
# 144     123622    2    241.0   51  145.0   85.0         1     20.0  25.66
# 154     127196    1    216.0   56  117.0   70.0         1     20.0  21.35
# 160     147250    1    229.0   68  145.0   77.0         1     20.0  23.09
# ...

# %%
HYP_3_df_final.isnull().sum()
# Out:
# RANDID      0
# SEX         0
# TOTCHOL     0
# AGE         0
# SYSBP       0
# DIABP       0
# CURSMOKE    0
# CIGPDAY     0
# BMI         0
# DIABETES    0
# BPMEDS      0
# HEARTRTE    0
# GLUCOSE     0
# PREVCHD     0
# PREVAP      0
# PREVSTRK    0
# PREVHYP     0
# TIME        0
# PERIOD      0
# DEATH       0
# HYPERTEN    0
# TIMEHYP     0
# dtype: int64

# %%
HYP_3_df_final.to_csv('../Resources/HYP_period3_data.csv', index=False)
