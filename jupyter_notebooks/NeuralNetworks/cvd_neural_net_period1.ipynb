# %% [markdown]
# # CVD - Neural Network

# %%
# Set the seed value for the notebook so the results are reproducible
from numpy.random import seed
seed(49)

# %%
# Dependencies
import numpy as np
import pandas as pd
import tensorflow
tensorflow.keras.__version__
# Out:
# '2.4.0'

# %%
df = pd.read_csv("Resources/cvd_period1_data.csv")
df.head()
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1    6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 2    9428    1    245.0   48  127.5   80.0         1     20.0  25.34
# 3   10552    2    225.0   61  150.0   95.0         1     30.0  28.58
# 4   11252    2    285.0   46  130.0   84.0         1     23.0  23.10
#
#    DIABETES  BPMEDS  HEARTRTE  GLUCOSE  PREVAP  PREVHYP  DEATH  CVD
# 0         0     0.0      80.0     77.0       0        0      0    1
# 1         0     0.0      95.0     76.0       0        0      0    0
# 2         0     0.0      75.0     70.0       0        0      0    0
# 3         0     0.0      65.0    103.0       0        1      1    1
# 4         0     0.0      85.0     85.0       0        0      0    0

# %% [markdown]
# ## Data Preprocessing

# %%
cvd_df = df.set_index('RANDID')
#Remove columns not involved in analysis
cvd_df = cvd_df[['SEX', 'TOTCHOL', 'AGE', 'SYSBP', 'DIABP', 'CURSMOKE',
       'CIGPDAY', 'BMI', 'DIABETES', 'BPMEDS', 'HEARTRTE', 'GLUCOSE', 'PREVAP',
       'PREVHYP', 'CVD']]
cvd_df.head()
# Out:
#         SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  DIABETES  \
# RANDID
# 2448      1    195.0   39  106.0   70.0         0      0.0  26.97         0
# 6238      2    250.0   46  121.0   81.0         0      0.0  28.73         0
# 9428      1    245.0   48  127.5   80.0         1     20.0  25.34         0
# 10552     2    225.0   61  150.0   95.0         1     30.0  28.58         0
# 11252     2    285.0   46  130.0   84.0         1     23.0  23.10         0
#
#         BPMEDS  HEARTRTE  GLUCOSE  PREVAP  PREVHYP  CVD
# RANDID
# 2448       0.0      80.0     77.0       0        0    1
# 6238       0.0      95.0     76.0       0        0    0
# 9428       0.0      75.0     70.0       0        0    0
# 10552      0.0      65.0    103.0       0        1    1
# 11252      0.0      85.0     85.0       0        0    0

# %%
X = cvd_df.drop("CVD", axis=1)
y = cvd_df["CVD"]
print(X.shape, y.shape)
# Out:
# (3730, 14) (3730,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)


# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# ## Create neural net model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create a Neural Network model here
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=14))
model.add(Dense(units=2, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               1500
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 1,702
# Trainable params: 1,702
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Fit the model to the training data
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2,
    batch_size = 1
)
# Out:
# Epoch 1/100
# 2797/2797 - 1s - loss: 0.5253 - accuracy: 0.7562
# Epoch 2/100
# 2797/2797 - 1s - loss: 0.5052 - accuracy: 0.7622
# Epoch 3/100
# 2797/2797 - 1s - loss: 0.4989 - accuracy: 0.7655
# Epoch 4/100
# 2797/2797 - 1s - loss: 0.4964 - accuracy: 0.7630
# Epoch 5/100
# 2797/2797 - 1s - loss: 0.4966 - accuracy: 0.7630
# Epoch 6/100
# 2797/2797 - 1s - loss: 0.4926 - accuracy: 0.7640
# Epoch 7/100
# 2797/2797 - 1s - loss: 0.4933 - accuracy: 0.7594
# Epoch 8/100
# 2797/2797 - 1s - loss: 0.4931 - accuracy: 0.7587
# Epoch 9/100
# 2797/2797 - 1s - loss: 0.4917 - accuracy: 0.7673
# Epoch 10/100
# 2797/2797 - 1s - loss: 0.4903 - accuracy: 0.7619
# Epoch 11/100
# 2797/2797 - 1s - loss: 0.4898 - accuracy: 0.7665
# Epoch 12/100
# 2797/2797 - 1s - loss: 0.4892 - accuracy: 0.7601
# Epoch 13/100
# 2797/2797 - 1s - loss: 0.4881 - accuracy: 0.7615
# Epoch 14/100
# 2797/2797 - 1s - loss: 0.4896 - accuracy: 0.7622
# Epoch 15/100
# 2797/2797 - 1s - loss: 0.4901 - accuracy: 0.7676
# Epoch 16/100
# 2797/2797 - 1s - loss: 0.4870 - accuracy: 0.7619
# Epoch 17/100
# 2797/2797 - 1s - loss: 0.4865 - accuracy: 0.7655
# Epoch 18/100
# 2797/2797 - 1s - loss: 0.4854 - accuracy: 0.7676
# Epoch 19/100
# 2797/2797 - 1s - loss: 0.4863 - accuracy: 0.7676
# Epoch 20/100
# 2797/2797 - 1s - loss: 0.4857 - accuracy: 0.7658
# Epoch 21/100
# 2797/2797 - 2s - loss: 0.4842 - accuracy: 0.7640
# Epoch 22/100
# 2797/2797 - 1s - loss: 0.4854 - accuracy: 0.7680
# Epoch 23/100
# 2797/2797 - 1s - loss: 0.4853 - accuracy: 0.7644
# Epoch 24/100
# 2797/2797 - 1s - loss: 0.4842 - accuracy: 0.7683
# Epoch 25/100
# 2797/2797 - 1s - loss: 0.4824 - accuracy: 0.7658
# Epoch 26/100
# 2797/2797 - 2s - loss: 0.4826 - accuracy: 0.7637
# Epoch 27/100
# 2797/2797 - 2s - loss: 0.4843 - accuracy: 0.7694
# Epoch 28/100
# 2797/2797 - 2s - loss: 0.4827 - accuracy: 0.7673
# Epoch 29/100
# 2797/2797 - 2s - loss: 0.4833 - accuracy: 0.7669
# Epoch 30/100
# 2797/2797 - 2s - loss: 0.4812 - accuracy: 0.7622
# Epoch 31/100
# 2797/2797 - 2s - loss: 0.4803 - accuracy: 0.7687
# Epoch 32/100
# 2797/2797 - 2s - loss: 0.4809 - accuracy: 0.7680
# Epoch 33/100
# 2797/2797 - 2s - loss: 0.4822 - accuracy: 0.7658
# Epoch 34/100
# 2797/2797 - 2s - loss: 0.4807 - accuracy: 0.7712
# Epoch 35/100
# 2797/2797 - 2s - loss: 0.4817 - accuracy: 0.7647
# Epoch 36/100
# 2797/2797 - 2s - loss: 0.4799 - accuracy: 0.7723
# Epoch 37/100
# 2797/2797 - 2s - loss: 0.4794 - accuracy: 0.7626
# Epoch 38/100
# 2797/2797 - 2s - loss: 0.4779 - accuracy: 0.7694
# Epoch 39/100
# 2797/2797 - 2s - loss: 0.4810 - accuracy: 0.7633
# Epoch 40/100
# 2797/2797 - 2s - loss: 0.4777 - accuracy: 0.7637
# Epoch 41/100
# 2797/2797 - 2s - loss: 0.4790 - accuracy: 0.7651
# Epoch 42/100
# 2797/2797 - 2s - loss: 0.4768 - accuracy: 0.7651
# Epoch 43/100
# 2797/2797 - 2s - loss: 0.4775 - accuracy: 0.7647
# Epoch 44/100
# 2797/2797 - 2s - loss: 0.4774 - accuracy: 0.7680
# Epoch 45/100
# 2797/2797 - 2s - loss: 0.4768 - accuracy: 0.7683
# Epoch 46/100
# 2797/2797 - 2s - loss: 0.4770 - accuracy: 0.7669
# Epoch 47/100
# 2797/2797 - 2s - loss: 0.4768 - accuracy: 0.7694
# Epoch 48/100
# 2797/2797 - 2s - loss: 0.4768 - accuracy: 0.7662
# Epoch 49/100
# 2797/2797 - 2s - loss: 0.4747 - accuracy: 0.7690
# Epoch 50/100
# 2797/2797 - 2s - loss: 0.4738 - accuracy: 0.7708
# Epoch 51/100
# 2797/2797 - 2s - loss: 0.4730 - accuracy: 0.7690
# Epoch 52/100
# 2797/2797 - 2s - loss: 0.4743 - accuracy: 0.7715
# Epoch 53/100
# 2797/2797 - 2s - loss: 0.4724 - accuracy: 0.7676
# Epoch 54/100
# 2797/2797 - 2s - loss: 0.4748 - accuracy: 0.7705
# Epoch 55/100
# 2797/2797 - 2s - loss: 0.4729 - accuracy: 0.7740
# Epoch 56/100
# 2797/2797 - 2s - loss: 0.4725 - accuracy: 0.7758
# Epoch 57/100
# 2797/2797 - 2s - loss: 0.4713 - accuracy: 0.7701
# Epoch 58/100
# 2797/2797 - 2s - loss: 0.4709 - accuracy: 0.7701
# Epoch 59/100
# 2797/2797 - 2s - loss: 0.4715 - accuracy: 0.7715
# Epoch 60/100
# 2797/2797 - 2s - loss: 0.4710 - accuracy: 0.7719
# Epoch 61/100
# 2797/2797 - 2s - loss: 0.4681 - accuracy: 0.7680
# Epoch 62/100
# 2797/2797 - 2s - loss: 0.4692 - accuracy: 0.7726
# Epoch 63/100
# 2797/2797 - 2s - loss: 0.4707 - accuracy: 0.7733
# Epoch 64/100
# 2797/2797 - 2s - loss: 0.4690 - accuracy: 0.7694
# Epoch 65/100
# 2797/2797 - 2s - loss: 0.4691 - accuracy: 0.7758
# Epoch 66/100
# 2797/2797 - 2s - loss: 0.4675 - accuracy: 0.7712
# Epoch 67/100
# 2797/2797 - 2s - loss: 0.4673 - accuracy: 0.7740
# Epoch 68/100
# 2797/2797 - 2s - loss: 0.4692 - accuracy: 0.7719
# Epoch 69/100
# 2797/2797 - 2s - loss: 0.4685 - accuracy: 0.7773
# Epoch 70/100
# 2797/2797 - 2s - loss: 0.4678 - accuracy: 0.7773
# Epoch 71/100
# 2797/2797 - 3s - loss: 0.4666 - accuracy: 0.7762
# Epoch 72/100
# 2797/2797 - 2s - loss: 0.4666 - accuracy: 0.7698
# Epoch 73/100
# 2797/2797 - 2s - loss: 0.4638 - accuracy: 0.7762
# Epoch 74/100
# 2797/2797 - 2s - loss: 0.4649 - accuracy: 0.7773
# Epoch 75/100
# 2797/2797 - 2s - loss: 0.4657 - accuracy: 0.7755
# Epoch 76/100
# 2797/2797 - 2s - loss: 0.4642 - accuracy: 0.7740
# Epoch 77/100
# 2797/2797 - 2s - loss: 0.4655 - accuracy: 0.7730
# Epoch 78/100
# 2797/2797 - 2s - loss: 0.4636 - accuracy: 0.7723
# Epoch 79/100
# 2797/2797 - 2s - loss: 0.4635 - accuracy: 0.7755
# Epoch 80/100
# 2797/2797 - 2s - loss: 0.4625 - accuracy: 0.7812
# Epoch 81/100
# 2797/2797 - 2s - loss: 0.4640 - accuracy: 0.7790
# Epoch 82/100
# 2797/2797 - 2s - loss: 0.4624 - accuracy: 0.7780
# Epoch 83/100
# 2797/2797 - 2s - loss: 0.4631 - accuracy: 0.7733
# Epoch 84/100
# 2797/2797 - 2s - loss: 0.4614 - accuracy: 0.7783
# Epoch 85/100
# 2797/2797 - 2s - loss: 0.4637 - accuracy: 0.7755
# Epoch 86/100
# 2797/2797 - 2s - loss: 0.4628 - accuracy: 0.7790
# Epoch 87/100
# 2797/2797 - 2s - loss: 0.4597 - accuracy: 0.7794
# Epoch 88/100
# 2797/2797 - 2s - loss: 0.4614 - accuracy: 0.7808
# Epoch 89/100
# 2797/2797 - 2s - loss: 0.4611 - accuracy: 0.7758
# Epoch 90/100
# 2797/2797 - 2s - loss: 0.4580 - accuracy: 0.7801
# Epoch 91/100
# 2797/2797 - 2s - loss: 0.4590 - accuracy: 0.7783
# Epoch 92/100
# 2797/2797 - 2s - loss: 0.4602 - accuracy: 0.7776
# Epoch 93/100
# 2797/2797 - 2s - loss: 0.4584 - accuracy: 0.7819
# Epoch 94/100
# 2797/2797 - 2s - loss: 0.4583 - accuracy: 0.7826
# Epoch 95/100
# 2797/2797 - 2s - loss: 0.4600 - accuracy: 0.7758
# Epoch 96/100
# 2797/2797 - 2s - loss: 0.4572 - accuracy: 0.7780
# Epoch 97/100
# 2797/2797 - 2s - loss: 0.4552 - accuracy: 0.7798
# Epoch 98/100
# 2797/2797 - 2s - loss: 0.4569 - accuracy: 0.7866
# Epoch 99/100
# 2797/2797 - 2s - loss: 0.4587 - accuracy: 0.7837
# Epoch 100/100
# 2797/2797 - 2s - loss: 0.4565 - accuracy: 0.7851

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2, batch_size=1)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 933/933 - 0s - loss: 0.4948 - accuracy: 0.7771
# Normal Neural Network - Loss: 0.49480628967285156, Accuracy: 0.777063250541687

# %% [markdown]
# ## Deep Learning Model

# %%
# Create a deep learning model with an extra hidden layer of 6 nodes called `deep_model`
deep_model = Sequential()
deep_model.add(Dense(units=100, activation='relu', input_dim=14))
deep_model.add(Dense(units=20, activation='relu'))
deep_model.add(Dense(units=2, activation='softmax'))

# %%
deep_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 100)               1500
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                2020
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 42
# =================================================================
# Total params: 3,562
# Trainable params: 3,562
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile and fit the deep_model
deep_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

deep_model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2,
    batch_size=1
)
# Out:
# Epoch 1/100
# 2797/2797 - 2s - loss: 0.5234 - accuracy: 0.7562
# Epoch 2/100
# 2797/2797 - 1s - loss: 0.5083 - accuracy: 0.7580
# Epoch 3/100
# 2797/2797 - 2s - loss: 0.5009 - accuracy: 0.7633
# Epoch 4/100
# 2797/2797 - 2s - loss: 0.5005 - accuracy: 0.7608
# Epoch 5/100
# 2797/2797 - 3s - loss: 0.4942 - accuracy: 0.7615
# Epoch 6/100
# 2797/2797 - 3s - loss: 0.4952 - accuracy: 0.7633
# Epoch 7/100
# 2797/2797 - 3s - loss: 0.4939 - accuracy: 0.7630
# Epoch 8/100
# 2797/2797 - 3s - loss: 0.4938 - accuracy: 0.7612
# Epoch 9/100
# 2797/2797 - 2s - loss: 0.4911 - accuracy: 0.7594
# Epoch 10/100
# 2797/2797 - 2s - loss: 0.4925 - accuracy: 0.7630
# Epoch 11/100
# 2797/2797 - 2s - loss: 0.4910 - accuracy: 0.7615
# Epoch 12/100
# 2797/2797 - 2s - loss: 0.4891 - accuracy: 0.7640
# Epoch 13/100
# 2797/2797 - 2s - loss: 0.4902 - accuracy: 0.7630
# Epoch 14/100
# 2797/2797 - 2s - loss: 0.4899 - accuracy: 0.7651
# Epoch 15/100
# 2797/2797 - 2s - loss: 0.4887 - accuracy: 0.7608
# Epoch 16/100
# 2797/2797 - 2s - loss: 0.4885 - accuracy: 0.7615
# Epoch 17/100
# 2797/2797 - 2s - loss: 0.4867 - accuracy: 0.7665
# Epoch 18/100
# 2797/2797 - 2s - loss: 0.4865 - accuracy: 0.7630
# Epoch 19/100
# 2797/2797 - 2s - loss: 0.4886 - accuracy: 0.7619
# Epoch 20/100
# 2797/2797 - 2s - loss: 0.4846 - accuracy: 0.7658
# Epoch 21/100
# 2797/2797 - 2s - loss: 0.4871 - accuracy: 0.7619
# Epoch 22/100
# 2797/2797 - 2s - loss: 0.4857 - accuracy: 0.7683
# Epoch 23/100
# 2797/2797 - 2s - loss: 0.4857 - accuracy: 0.7651
# Epoch 24/100
# 2797/2797 - 2s - loss: 0.4827 - accuracy: 0.7662
# Epoch 25/100
# 2797/2797 - 2s - loss: 0.4841 - accuracy: 0.7615
# Epoch 26/100
# 2797/2797 - 2s - loss: 0.4835 - accuracy: 0.7665
# Epoch 27/100
# 2797/2797 - 2s - loss: 0.4829 - accuracy: 0.7701
# Epoch 28/100
# 2797/2797 - 2s - loss: 0.4821 - accuracy: 0.7655
# Epoch 29/100
# 2797/2797 - 2s - loss: 0.4819 - accuracy: 0.7676
# Epoch 30/100
# 2797/2797 - 2s - loss: 0.4811 - accuracy: 0.7669
# Epoch 31/100
# 2797/2797 - 2s - loss: 0.4802 - accuracy: 0.7665
# Epoch 32/100
# 2797/2797 - 2s - loss: 0.4798 - accuracy: 0.7662
# Epoch 33/100
# 2797/2797 - 2s - loss: 0.4814 - accuracy: 0.7694
# Epoch 34/100
# 2797/2797 - 2s - loss: 0.4792 - accuracy: 0.7680
# Epoch 35/100
# 2797/2797 - 2s - loss: 0.4809 - accuracy: 0.7683
# Epoch 36/100
# 2797/2797 - 2s - loss: 0.4783 - accuracy: 0.7655
# Epoch 37/100
# 2797/2797 - 2s - loss: 0.4785 - accuracy: 0.7662
# Epoch 38/100
# 2797/2797 - 2s - loss: 0.4797 - accuracy: 0.7655
# Epoch 39/100
# 2797/2797 - 2s - loss: 0.4771 - accuracy: 0.7673
# Epoch 40/100
# 2797/2797 - 2s - loss: 0.4788 - accuracy: 0.7612
# Epoch 41/100
# 2797/2797 - 2s - loss: 0.4772 - accuracy: 0.7673
# Epoch 42/100
# 2797/2797 - 2s - loss: 0.4774 - accuracy: 0.7633
# Epoch 43/100
# 2797/2797 - 2s - loss: 0.4764 - accuracy: 0.7683
# Epoch 44/100
# 2797/2797 - 2s - loss: 0.4774 - accuracy: 0.7683
# Epoch 45/100
# 2797/2797 - 2s - loss: 0.4756 - accuracy: 0.7708
# Epoch 46/100
# 2797/2797 - 2s - loss: 0.4759 - accuracy: 0.7708
# Epoch 47/100
# 2797/2797 - 2s - loss: 0.4740 - accuracy: 0.7737
# Epoch 48/100
# 2797/2797 - 2s - loss: 0.4761 - accuracy: 0.7662
# Epoch 49/100
# 2797/2797 - 2s - loss: 0.4742 - accuracy: 0.7690
# Epoch 50/100
# 2797/2797 - 2s - loss: 0.4698 - accuracy: 0.7733
# Epoch 51/100
# 2797/2797 - 2s - loss: 0.4733 - accuracy: 0.7687
# Epoch 52/100
# 2797/2797 - 2s - loss: 0.4730 - accuracy: 0.7690
# Epoch 53/100
# 2797/2797 - 2s - loss: 0.4731 - accuracy: 0.7726
# Epoch 54/100
# 2797/2797 - 2s - loss: 0.4701 - accuracy: 0.7708
# Epoch 55/100
# 2797/2797 - 2s - loss: 0.4708 - accuracy: 0.7680
# Epoch 56/100
# 2797/2797 - 2s - loss: 0.4726 - accuracy: 0.7755
# Epoch 57/100
# 2797/2797 - 2s - loss: 0.4684 - accuracy: 0.7748
# Epoch 58/100
# 2797/2797 - 2s - loss: 0.4709 - accuracy: 0.7726
# Epoch 59/100
# 2797/2797 - 2s - loss: 0.4698 - accuracy: 0.7740
# Epoch 60/100
# 2797/2797 - 2s - loss: 0.4679 - accuracy: 0.7687
# Epoch 61/100
# 2797/2797 - 2s - loss: 0.4707 - accuracy: 0.7733
# Epoch 62/100
# 2797/2797 - 2s - loss: 0.4676 - accuracy: 0.7665
# Epoch 63/100
# 2797/2797 - 3s - loss: 0.4671 - accuracy: 0.7726
# Epoch 64/100
# 2797/2797 - 3s - loss: 0.4650 - accuracy: 0.7801
# Epoch 65/100
# 2797/2797 - 2s - loss: 0.4642 - accuracy: 0.7737
# Epoch 66/100
# 2797/2797 - 2s - loss: 0.4643 - accuracy: 0.7719
# Epoch 67/100
# 2797/2797 - 2s - loss: 0.4666 - accuracy: 0.7715
# Epoch 68/100
# 2797/2797 - 2s - loss: 0.4667 - accuracy: 0.7705
# Epoch 69/100
# 2797/2797 - 2s - loss: 0.4655 - accuracy: 0.7762
# Epoch 70/100
# 2797/2797 - 2s - loss: 0.4640 - accuracy: 0.7712
# Epoch 71/100
# 2797/2797 - 2s - loss: 0.4611 - accuracy: 0.7798
# Epoch 72/100
# 2797/2797 - 2s - loss: 0.4628 - accuracy: 0.7790
# Epoch 73/100
# 2797/2797 - 2s - loss: 0.4611 - accuracy: 0.7758
# Epoch 74/100
# 2797/2797 - 2s - loss: 0.4622 - accuracy: 0.7765
# Epoch 75/100
# 2797/2797 - 2s - loss: 0.4612 - accuracy: 0.7790
# Epoch 76/100
# 2797/2797 - 2s - loss: 0.4612 - accuracy: 0.7783
# Epoch 77/100
# 2797/2797 - 2s - loss: 0.4594 - accuracy: 0.7787
# Epoch 78/100
# 2797/2797 - 2s - loss: 0.4574 - accuracy: 0.7794
# Epoch 79/100
# 2797/2797 - 2s - loss: 0.4593 - accuracy: 0.7783
# Epoch 80/100
# 2797/2797 - 2s - loss: 0.4549 - accuracy: 0.7798
# Epoch 81/100
# 2797/2797 - 2s - loss: 0.4559 - accuracy: 0.7765
# Epoch 82/100
# 2797/2797 - 2s - loss: 0.4595 - accuracy: 0.7758
# Epoch 83/100
# 2797/2797 - 2s - loss: 0.4545 - accuracy: 0.7855
# Epoch 84/100
# 2797/2797 - 2s - loss: 0.4554 - accuracy: 0.7833
# Epoch 85/100
# 2797/2797 - 2s - loss: 0.4553 - accuracy: 0.7783
# Epoch 86/100
# 2797/2797 - 2s - loss: 0.4557 - accuracy: 0.7794
# Epoch 87/100
# 2797/2797 - 2s - loss: 0.4509 - accuracy: 0.7833
# Epoch 88/100
# 2797/2797 - 2s - loss: 0.4538 - accuracy: 0.7844
# Epoch 89/100
# 2797/2797 - 2s - loss: 0.4568 - accuracy: 0.7787
# Epoch 90/100
# 2797/2797 - 2s - loss: 0.4519 - accuracy: 0.7841
# Epoch 91/100
# 2797/2797 - 2s - loss: 0.4496 - accuracy: 0.7873
# Epoch 92/100
# 2797/2797 - 2s - loss: 0.4490 - accuracy: 0.7844
# Epoch 93/100
# 2797/2797 - 2s - loss: 0.4501 - accuracy: 0.7855
# Epoch 94/100
# 2797/2797 - 2s - loss: 0.4463 - accuracy: 0.7801
# Epoch 95/100
# 2797/2797 - 2s - loss: 0.4523 - accuracy: 0.7798
# Epoch 96/100
# 2797/2797 - 2s - loss: 0.4464 - accuracy: 0.7869
# Epoch 97/100
# 2797/2797 - 2s - loss: 0.4449 - accuracy: 0.7869
# Epoch 98/100
# 2797/2797 - 2s - loss: 0.4468 - accuracy: 0.7869
# Epoch 99/100
# 2797/2797 - 2s - loss: 0.4460 - accuracy: 0.7880
# Epoch 100/100
# 2797/2797 - 2s - loss: 0.4416 - accuracy: 0.7876

# %%
model_loss, model_accuracy = deep_model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2, batch_size=1)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 933/933 - 0s - loss: 0.5527 - accuracy: 0.7663
# Deep Neural Network - Loss: 0.5526836514472961, Accuracy: 0.7663451433181763
