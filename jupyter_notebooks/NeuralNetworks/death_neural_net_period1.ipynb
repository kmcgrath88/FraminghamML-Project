# %% [markdown]
# # Death - Neural Network

# %%
# Set the seed value for the notebook so the results are reproducible
from numpy.random import seed
seed(49)

# %%
# Dependencies
import numpy as np
import pandas as pd
import tensorflow
tensorflow.keras.__version__
# Out:
# '2.4.0'

# %%
df = pd.read_csv("Resources/period1_final_data.csv")
df.head()
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1    6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 2    9428    1    245.0   48  127.5   80.0         1     20.0  25.34
# 3   10552    2    225.0   61  150.0   95.0         1     30.0  28.58
# 4   11252    2    285.0   46  130.0   84.0         1     23.0  23.10
#
#    DIABETES  ...  CVD  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0         0  ...    1         0    8766    6438      6438     6438      8766
# 1         0  ...    0         0    8766    8766      8766     8766      8766
# 2         0  ...    0         0    8766    8766      8766     8766      8766
# 3         0  ...    1         1    2956    2956      2956     2956      2089
# 4         0  ...    0         1    8766    8766      8766     8766      8766
#
#    TIMECVD  TIMEDTH  TIMEHYP
# 0     6438     8766     8766
# 1     8766     8766     8766
# 2     8766     8766     8766
# 3     2089     2956        0
# 4     8766     8766     4285
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
death_df = df.set_index('RANDID')
#Remove columns not involved in analysis
death_df = death_df[['SEX', 'TOTCHOL', 'AGE', 'SYSBP', 'DIABP', 'CURSMOKE', 'CIGPDAY', 'BMI',
       'DIABETES', 'BPMEDS', 'HEARTRTE', 'GLUCOSE', 'PREVCHD', 'PREVAP',
       'PREVMI', 'PREVSTRK', 'PREVHYP', 'DEATH']]
death_df.head()
# Out:
#         SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  DIABETES  \
# RANDID
# 2448      1    195.0   39  106.0   70.0         0      0.0  26.97         0
# 6238      2    250.0   46  121.0   81.0         0      0.0  28.73         0
# 9428      1    245.0   48  127.5   80.0         1     20.0  25.34         0
# 10552     2    225.0   61  150.0   95.0         1     30.0  28.58         0
# 11252     2    285.0   46  130.0   84.0         1     23.0  23.10         0
#
#         BPMEDS  HEARTRTE  GLUCOSE  PREVCHD  PREVAP  PREVMI  PREVSTRK  PREVHYP  \
# RANDID
# 2448       0.0      80.0     77.0        0       0       0         0        0
# 6238       0.0      95.0     76.0        0       0       0         0        0
# 9428       0.0      75.0     70.0        0       0       0         0        0
# 10552      0.0      65.0    103.0        0       0       0         0        1
# 11252      0.0      85.0     85.0        0       0       0         0        0
#
#         DEATH
# RANDID
# 2448        0
# 6238        0
# 9428        0
# 10552       1
# 11252       0

# %%
X = death_df.drop("DEATH", axis=1)
y = death_df["DEATH"]
target_names = ["negative", "positive"]
print(X.shape, y.shape)
# Out:
# (3927, 17) (3927,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)


# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# ## Create neural net model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create a Neural Network model here
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=17))
model.add(Dense(units=2, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               1800
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 2,002
# Trainable params: 2,002
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Fit the model to the training data
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2,
    batch_size = 1
)
# Out:
# Epoch 1/100
# 2945/2945 - 1s - loss: 0.5549 - accuracy: 0.7229
# Epoch 2/100
# 2945/2945 - 1s - loss: 0.5180 - accuracy: 0.7552
# Epoch 3/100
# 2945/2945 - 1s - loss: 0.5104 - accuracy: 0.7572
# Epoch 4/100
# 2945/2945 - 1s - loss: 0.5051 - accuracy: 0.7589
# Epoch 5/100
# 2945/2945 - 1s - loss: 0.5072 - accuracy: 0.7596
# Epoch 6/100
# 2945/2945 - 1s - loss: 0.5020 - accuracy: 0.7637
# Epoch 7/100
# 2945/2945 - 1s - loss: 0.5002 - accuracy: 0.7657
# Epoch 8/100
# 2945/2945 - 1s - loss: 0.5002 - accuracy: 0.7613
# Epoch 9/100
# 2945/2945 - 1s - loss: 0.4965 - accuracy: 0.7623
# Epoch 10/100
# 2945/2945 - 1s - loss: 0.4976 - accuracy: 0.7599
# Epoch 11/100
# 2945/2945 - 1s - loss: 0.4958 - accuracy: 0.7640
# Epoch 12/100
# 2945/2945 - 1s - loss: 0.4946 - accuracy: 0.7698
# Epoch 13/100
# 2945/2945 - 1s - loss: 0.4930 - accuracy: 0.7657
# Epoch 14/100
# 2945/2945 - 1s - loss: 0.4945 - accuracy: 0.7654
# Epoch 15/100
# 2945/2945 - 1s - loss: 0.4909 - accuracy: 0.7640
# Epoch 16/100
# 2945/2945 - 1s - loss: 0.4927 - accuracy: 0.7667
# Epoch 17/100
# 2945/2945 - 1s - loss: 0.4908 - accuracy: 0.7637
# Epoch 18/100
# 2945/2945 - 1s - loss: 0.4870 - accuracy: 0.7684
# Epoch 19/100
# 2945/2945 - 1s - loss: 0.4879 - accuracy: 0.7708
# Epoch 20/100
# 2945/2945 - 1s - loss: 0.4883 - accuracy: 0.7705
# Epoch 21/100
# 2945/2945 - 1s - loss: 0.4883 - accuracy: 0.7671
# Epoch 22/100
# 2945/2945 - 1s - loss: 0.4870 - accuracy: 0.7650
# Epoch 23/100
# 2945/2945 - 1s - loss: 0.4878 - accuracy: 0.7681
# Epoch 24/100
# 2945/2945 - 1s - loss: 0.4847 - accuracy: 0.7677
# Epoch 25/100
# 2945/2945 - 1s - loss: 0.4852 - accuracy: 0.7742
# Epoch 26/100
# 2945/2945 - 1s - loss: 0.4852 - accuracy: 0.7772
# Epoch 27/100
# 2945/2945 - 1s - loss: 0.4835 - accuracy: 0.7722
# Epoch 28/100
# 2945/2945 - 1s - loss: 0.4828 - accuracy: 0.7752
# Epoch 29/100
# 2945/2945 - 1s - loss: 0.4828 - accuracy: 0.7725
# Epoch 30/100
# 2945/2945 - 1s - loss: 0.4800 - accuracy: 0.7735
# Epoch 31/100
# 2945/2945 - 1s - loss: 0.4805 - accuracy: 0.7711
# Epoch 32/100
# 2945/2945 - 1s - loss: 0.4776 - accuracy: 0.7796
# Epoch 33/100
# 2945/2945 - 1s - loss: 0.4785 - accuracy: 0.7749
# Epoch 34/100
# 2945/2945 - 1s - loss: 0.4785 - accuracy: 0.7745
# Epoch 35/100
# 2945/2945 - 1s - loss: 0.4751 - accuracy: 0.7776
# Epoch 36/100
# 2945/2945 - 1s - loss: 0.4772 - accuracy: 0.7783
# Epoch 37/100
# 2945/2945 - 1s - loss: 0.4743 - accuracy: 0.7752
# Epoch 38/100
# 2945/2945 - 1s - loss: 0.4750 - accuracy: 0.7762
# Epoch 39/100
# 2945/2945 - 1s - loss: 0.4742 - accuracy: 0.7718
# Epoch 40/100
# 2945/2945 - 1s - loss: 0.4741 - accuracy: 0.7772
# Epoch 41/100
# 2945/2945 - 1s - loss: 0.4714 - accuracy: 0.7759
# Epoch 42/100
# 2945/2945 - 1s - loss: 0.4711 - accuracy: 0.7745
# Epoch 43/100
# 2945/2945 - 1s - loss: 0.4706 - accuracy: 0.7813
# Epoch 44/100
# 2945/2945 - 1s - loss: 0.4697 - accuracy: 0.7813
# Epoch 45/100
# 2945/2945 - 1s - loss: 0.4716 - accuracy: 0.7735
# Epoch 46/100
# 2945/2945 - 1s - loss: 0.4690 - accuracy: 0.7776
# Epoch 47/100
# 2945/2945 - 1s - loss: 0.4685 - accuracy: 0.7806
# Epoch 48/100
# 2945/2945 - 1s - loss: 0.4693 - accuracy: 0.7813
# Epoch 49/100
# 2945/2945 - 1s - loss: 0.4664 - accuracy: 0.7756
# Epoch 50/100
# 2945/2945 - 1s - loss: 0.4669 - accuracy: 0.7851
# Epoch 51/100
# 2945/2945 - 1s - loss: 0.4635 - accuracy: 0.7830
# Epoch 52/100
# 2945/2945 - 1s - loss: 0.4634 - accuracy: 0.7813
# Epoch 53/100
# 2945/2945 - 1s - loss: 0.4639 - accuracy: 0.7874
# Epoch 54/100
# 2945/2945 - 1s - loss: 0.4619 - accuracy: 0.7796
# Epoch 55/100
# 2945/2945 - 1s - loss: 0.4641 - accuracy: 0.7864
# Epoch 56/100
# 2945/2945 - 1s - loss: 0.4621 - accuracy: 0.7823
# Epoch 57/100
# 2945/2945 - 1s - loss: 0.4609 - accuracy: 0.7834
# Epoch 58/100
# 2945/2945 - 1s - loss: 0.4601 - accuracy: 0.7800
# Epoch 59/100
# 2945/2945 - 1s - loss: 0.4614 - accuracy: 0.7823
# Epoch 60/100
# 2945/2945 - 1s - loss: 0.4599 - accuracy: 0.7881
# Epoch 61/100
# 2945/2945 - 1s - loss: 0.4580 - accuracy: 0.7885
# Epoch 62/100
# 2945/2945 - 1s - loss: 0.4568 - accuracy: 0.7834
# Epoch 63/100
# 2945/2945 - 1s - loss: 0.4561 - accuracy: 0.7857
# Epoch 64/100
# 2945/2945 - 1s - loss: 0.4567 - accuracy: 0.7820
# Epoch 65/100
# 2945/2945 - 1s - loss: 0.4550 - accuracy: 0.7837
# Epoch 66/100
# 2945/2945 - 1s - loss: 0.4530 - accuracy: 0.7891
# Epoch 67/100
# 2945/2945 - 1s - loss: 0.4553 - accuracy: 0.7891
# Epoch 68/100
# 2945/2945 - 1s - loss: 0.4519 - accuracy: 0.7898
# Epoch 69/100
# 2945/2945 - 1s - loss: 0.4546 - accuracy: 0.7885
# Epoch 70/100
# 2945/2945 - 1s - loss: 0.4539 - accuracy: 0.7922
# Epoch 71/100
# 2945/2945 - 1s - loss: 0.4506 - accuracy: 0.7898
# Epoch 72/100
# 2945/2945 - 1s - loss: 0.4519 - accuracy: 0.7929
# Epoch 73/100
# 2945/2945 - 1s - loss: 0.4525 - accuracy: 0.7932
# Epoch 74/100
# 2945/2945 - 1s - loss: 0.4484 - accuracy: 0.7905
# Epoch 75/100
# 2945/2945 - 1s - loss: 0.4511 - accuracy: 0.7868
# Epoch 76/100
# 2945/2945 - 1s - loss: 0.4526 - accuracy: 0.7847
# Epoch 77/100
# 2945/2945 - 1s - loss: 0.4480 - accuracy: 0.7895
# Epoch 78/100
# 2945/2945 - 1s - loss: 0.4499 - accuracy: 0.7891
# Epoch 79/100
# 2945/2945 - 1s - loss: 0.4472 - accuracy: 0.7932
# Epoch 80/100
# 2945/2945 - 1s - loss: 0.4461 - accuracy: 0.7908
# Epoch 81/100
# 2945/2945 - 1s - loss: 0.4466 - accuracy: 0.7898
# Epoch 82/100
# 2945/2945 - 1s - loss: 0.4446 - accuracy: 0.7952
# Epoch 83/100
# 2945/2945 - 1s - loss: 0.4431 - accuracy: 0.7956
# Epoch 84/100
# 2945/2945 - 1s - loss: 0.4435 - accuracy: 0.7898
# Epoch 85/100
# 2945/2945 - 1s - loss: 0.4473 - accuracy: 0.7932
# Epoch 86/100
# 2945/2945 - 1s - loss: 0.4432 - accuracy: 0.7956
# Epoch 87/100
# 2945/2945 - 1s - loss: 0.4420 - accuracy: 0.7949
# Epoch 88/100
# 2945/2945 - 1s - loss: 0.4421 - accuracy: 0.7952
# Epoch 89/100
# 2945/2945 - 1s - loss: 0.4420 - accuracy: 0.7925
# Epoch 90/100
# 2945/2945 - 1s - loss: 0.4416 - accuracy: 0.7919
# Epoch 91/100
# 2945/2945 - 1s - loss: 0.4397 - accuracy: 0.7878
# Epoch 92/100
# 2945/2945 - 1s - loss: 0.4393 - accuracy: 0.7929
# Epoch 93/100
# 2945/2945 - 1s - loss: 0.4387 - accuracy: 0.7946
# Epoch 94/100
# 2945/2945 - 1s - loss: 0.4375 - accuracy: 0.7997
# Epoch 95/100
# 2945/2945 - 1s - loss: 0.4366 - accuracy: 0.7952
# Epoch 96/100
# 2945/2945 - 1s - loss: 0.4379 - accuracy: 0.7898
# Epoch 97/100
# 2945/2945 - 2s - loss: 0.4382 - accuracy: 0.7993
# Epoch 98/100
# 2945/2945 - 2s - loss: 0.4338 - accuracy: 0.7976
# Epoch 99/100
# 2945/2945 - 1s - loss: 0.4364 - accuracy: 0.7976
# Epoch 100/100
# 2945/2945 - 1s - loss: 0.4375 - accuracy: 0.7973

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2, batch_size=1)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 982/982 - 0s - loss: 0.5927 - accuracy: 0.7363
# Normal Neural Network - Loss: 0.5926727056503296, Accuracy: 0.7362525463104248

# %% [markdown]
# ## Deep Learning Model

# %%
# Create a deep learning model with an extra hidden layer of 6 nodes called `deep_model`
deep_model = Sequential()
deep_model.add(Dense(units=100, activation='relu', input_dim=17))
deep_model.add(Dense(units=20, activation='relu'))
deep_model.add(Dense(units=2, activation='softmax'))

# %%
deep_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 100)               1800
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                2020
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 42
# =================================================================
# Total params: 3,862
# Trainable params: 3,862
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile and fit the deep_model
deep_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

deep_model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2,
    batch_size=1
)
# Out:
# Epoch 1/100
# 2945/2945 - 1s - loss: 0.5549 - accuracy: 0.7243
# Epoch 2/100
# 2945/2945 - 1s - loss: 0.5209 - accuracy: 0.7453
# Epoch 3/100
# 2945/2945 - 1s - loss: 0.5135 - accuracy: 0.7548
# Epoch 4/100
# 2945/2945 - 1s - loss: 0.5104 - accuracy: 0.7572
# Epoch 5/100
# 2945/2945 - 1s - loss: 0.5052 - accuracy: 0.7623
# Epoch 6/100
# 2945/2945 - 1s - loss: 0.5055 - accuracy: 0.7589
# Epoch 7/100
# 2945/2945 - 1s - loss: 0.5039 - accuracy: 0.7582
# Epoch 8/100
# 2945/2945 - 1s - loss: 0.4986 - accuracy: 0.7633
# Epoch 9/100
# 2945/2945 - 1s - loss: 0.4997 - accuracy: 0.7664
# Epoch 10/100
# 2945/2945 - 1s - loss: 0.4964 - accuracy: 0.7664
# Epoch 11/100
# 2945/2945 - 1s - loss: 0.4966 - accuracy: 0.7654
# Epoch 12/100
# 2945/2945 - 1s - loss: 0.4940 - accuracy: 0.7657
# Epoch 13/100
# 2945/2945 - 1s - loss: 0.4947 - accuracy: 0.7630
# Epoch 14/100
# 2945/2945 - 1s - loss: 0.4929 - accuracy: 0.7698
# Epoch 15/100
# 2945/2945 - 1s - loss: 0.4912 - accuracy: 0.7688
# Epoch 16/100
# 2945/2945 - 1s - loss: 0.4893 - accuracy: 0.7715
# Epoch 17/100
# 2945/2945 - 1s - loss: 0.4889 - accuracy: 0.7681
# Epoch 18/100
# 2945/2945 - 1s - loss: 0.4894 - accuracy: 0.7684
# Epoch 19/100
# 2945/2945 - 1s - loss: 0.4887 - accuracy: 0.7633
# Epoch 20/100
# 2945/2945 - 1s - loss: 0.4874 - accuracy: 0.7711
# Epoch 21/100
# 2945/2945 - 1s - loss: 0.4858 - accuracy: 0.7698
# Epoch 22/100
# 2945/2945 - 1s - loss: 0.4861 - accuracy: 0.7752
# Epoch 23/100
# 2945/2945 - 1s - loss: 0.4818 - accuracy: 0.7756
# Epoch 24/100
# 2945/2945 - 1s - loss: 0.4825 - accuracy: 0.7722
# Epoch 25/100
# 2945/2945 - 1s - loss: 0.4817 - accuracy: 0.7742
# Epoch 26/100
# 2945/2945 - 1s - loss: 0.4806 - accuracy: 0.7722
# Epoch 27/100
# 2945/2945 - 1s - loss: 0.4796 - accuracy: 0.7749
# Epoch 28/100
# 2945/2945 - 1s - loss: 0.4808 - accuracy: 0.7759
# Epoch 29/100
# 2945/2945 - 1s - loss: 0.4757 - accuracy: 0.7766
# Epoch 30/100
# 2945/2945 - 1s - loss: 0.4735 - accuracy: 0.7779
# Epoch 31/100
# 2945/2945 - 1s - loss: 0.4755 - accuracy: 0.7783
# Epoch 32/100
# 2945/2945 - 1s - loss: 0.4735 - accuracy: 0.7779
# Epoch 33/100
# 2945/2945 - 1s - loss: 0.4708 - accuracy: 0.7752
# Epoch 34/100
# 2945/2945 - 1s - loss: 0.4713 - accuracy: 0.7749
# Epoch 35/100
# 2945/2945 - 1s - loss: 0.4694 - accuracy: 0.7789
# Epoch 36/100
# 2945/2945 - 1s - loss: 0.4680 - accuracy: 0.7830
# Epoch 37/100
# 2945/2945 - 1s - loss: 0.4669 - accuracy: 0.7837
# Epoch 38/100
# 2945/2945 - 1s - loss: 0.4659 - accuracy: 0.7820
# Epoch 39/100
# 2945/2945 - 1s - loss: 0.4650 - accuracy: 0.7817
# Epoch 40/100
# 2945/2945 - 1s - loss: 0.4636 - accuracy: 0.7783
# Epoch 41/100
# 2945/2945 - 1s - loss: 0.4626 - accuracy: 0.7813
# Epoch 42/100
# 2945/2945 - 1s - loss: 0.4623 - accuracy: 0.7806
# Epoch 43/100
# 2945/2945 - 1s - loss: 0.4610 - accuracy: 0.7840
# Epoch 44/100
# 2945/2945 - 1s - loss: 0.4591 - accuracy: 0.7806
# Epoch 45/100
# 2945/2945 - 1s - loss: 0.4601 - accuracy: 0.7840
# Epoch 46/100
# 2945/2945 - 1s - loss: 0.4586 - accuracy: 0.7874
# Epoch 47/100
# 2945/2945 - 1s - loss: 0.4527 - accuracy: 0.7854
# Epoch 48/100
# 2945/2945 - 1s - loss: 0.4520 - accuracy: 0.7820
# Epoch 49/100
# 2945/2945 - 1s - loss: 0.4538 - accuracy: 0.7878
# Epoch 50/100
# 2945/2945 - 1s - loss: 0.4552 - accuracy: 0.7895
# Epoch 51/100
# 2945/2945 - 1s - loss: 0.4521 - accuracy: 0.7864
# Epoch 52/100
# 2945/2945 - 1s - loss: 0.4530 - accuracy: 0.7823
# Epoch 53/100
# 2945/2945 - 1s - loss: 0.4495 - accuracy: 0.7878
# Epoch 54/100
# 2945/2945 - 1s - loss: 0.4504 - accuracy: 0.7871
# Epoch 55/100
# 2945/2945 - 1s - loss: 0.4490 - accuracy: 0.7905
# Epoch 56/100
# 2945/2945 - 1s - loss: 0.4484 - accuracy: 0.7878
# Epoch 57/100
# 2945/2945 - 1s - loss: 0.4489 - accuracy: 0.7857
# Epoch 58/100
# 2945/2945 - 1s - loss: 0.4450 - accuracy: 0.7956
# Epoch 59/100
# 2945/2945 - 1s - loss: 0.4472 - accuracy: 0.7956
# Epoch 60/100
# 2945/2945 - 1s - loss: 0.4433 - accuracy: 0.7898
# Epoch 61/100
# 2945/2945 - 1s - loss: 0.4406 - accuracy: 0.7959
# Epoch 62/100
# 2945/2945 - 1s - loss: 0.4416 - accuracy: 0.7915
# Epoch 63/100
# 2945/2945 - 1s - loss: 0.4434 - accuracy: 0.7973
# Epoch 64/100
# 2945/2945 - 2s - loss: 0.4399 - accuracy: 0.7946
# Epoch 65/100
# 2945/2945 - 2s - loss: 0.4394 - accuracy: 0.7922
# Epoch 66/100
# 2945/2945 - 1s - loss: 0.4357 - accuracy: 0.7929
# Epoch 67/100
# 2945/2945 - 1s - loss: 0.4376 - accuracy: 0.7949
# Epoch 68/100
# 2945/2945 - 2s - loss: 0.4339 - accuracy: 0.8003
# Epoch 69/100
# 2945/2945 - 1s - loss: 0.4331 - accuracy: 0.7986
# Epoch 70/100
# 2945/2945 - 1s - loss: 0.4416 - accuracy: 0.7946
# Epoch 71/100
# 2945/2945 - 1s - loss: 0.4330 - accuracy: 0.7963
# Epoch 72/100
# 2945/2945 - 1s - loss: 0.4312 - accuracy: 0.8020
# Epoch 73/100
# 2945/2945 - 1s - loss: 0.4327 - accuracy: 0.7922
# Epoch 74/100
# 2945/2945 - 1s - loss: 0.4275 - accuracy: 0.8000
# Epoch 75/100
# 2945/2945 - 2s - loss: 0.4327 - accuracy: 0.7935
# Epoch 76/100
# 2945/2945 - 2s - loss: 0.4313 - accuracy: 0.7983
# Epoch 77/100
# 2945/2945 - 2s - loss: 0.4285 - accuracy: 0.7980
# Epoch 78/100
# 2945/2945 - 2s - loss: 0.4267 - accuracy: 0.8031
# Epoch 79/100
# 2945/2945 - 2s - loss: 0.4241 - accuracy: 0.8068
# Epoch 80/100
# 2945/2945 - 2s - loss: 0.4248 - accuracy: 0.8014
# Epoch 81/100
# 2945/2945 - 2s - loss: 0.4218 - accuracy: 0.8075
# Epoch 82/100
# 2945/2945 - 2s - loss: 0.4217 - accuracy: 0.7959
# Epoch 83/100
# 2945/2945 - 2s - loss: 0.4245 - accuracy: 0.8051
# Epoch 84/100
# 2945/2945 - 1s - loss: 0.4250 - accuracy: 0.8027
# Epoch 85/100
# 2945/2945 - 1s - loss: 0.4179 - accuracy: 0.8065
# Epoch 86/100
# 2945/2945 - 1s - loss: 0.4208 - accuracy: 0.8051
# Epoch 87/100
# 2945/2945 - 1s - loss: 0.4173 - accuracy: 0.8027
# Epoch 88/100
# 2945/2945 - 1s - loss: 0.4220 - accuracy: 0.7990
# Epoch 89/100
# 2945/2945 - 2s - loss: 0.4166 - accuracy: 0.8024
# Epoch 90/100
# 2945/2945 - 2s - loss: 0.4176 - accuracy: 0.8007
# Epoch 91/100
# 2945/2945 - 1s - loss: 0.4130 - accuracy: 0.8024
# Epoch 92/100
# 2945/2945 - 1s - loss: 0.4117 - accuracy: 0.8085
# Epoch 93/100
# 2945/2945 - 1s - loss: 0.4150 - accuracy: 0.8081
# Epoch 94/100
# 2945/2945 - 1s - loss: 0.4178 - accuracy: 0.8027
# Epoch 95/100
# 2945/2945 - 1s - loss: 0.4116 - accuracy: 0.8061
# Epoch 96/100
# 2945/2945 - 1s - loss: 0.4098 - accuracy: 0.8051
# Epoch 97/100
# 2945/2945 - 1s - loss: 0.4078 - accuracy: 0.8081
# Epoch 98/100
# 2945/2945 - 1s - loss: 0.4085 - accuracy: 0.8068
# Epoch 99/100
# 2945/2945 - 1s - loss: 0.4115 - accuracy: 0.8054
# Epoch 100/100
# 2945/2945 - 1s - loss: 0.4032 - accuracy: 0.8109

# %%
model_loss, model_accuracy = deep_model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2, batch_size=1)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 982/982 - 0s - loss: 0.8514 - accuracy: 0.7475
# Deep Neural Network - Loss: 0.8513874411582947, Accuracy: 0.7474541664123535
