# %%
import pandas as pd

# %%
df = pd.read_csv('../Resources/HYP_final_data.csv')
df.head()
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1    6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 2    9428    1    245.0   48  127.5   80.0         1     20.0  25.34
# 3   11252    2    285.0   46  130.0   84.0         1     23.0  23.10
# 4   12629    2    205.0   63  138.0   71.0         0      0.0  33.11
#
#    DIABETES   ...     GLUCOSE  PREVCHD  PREVAP  PREVSTRK  PREVHYP  TIME  \
# 0         0   ...        77.0        0       0         0        0     0
# 1         0   ...        76.0        0       0         0        0     0
# 2         0   ...        70.0        0       0         0        0     0
# 3         0   ...        85.0        0       0         0        0     0
# 4         0   ...        85.0        0       0         0        0     0
#
#    PERIOD  DEATH  HYPERTEN  TIMEHYP
# 0       1      0         0     8766
# 1       1      0         0     8766
# 2       1      0         0     8766
# 3       1      0         1     4285
# 4       1      0         1     2212
#
# [5 rows x 22 columns]

# %%
HYP_df = df.set_index('RANDID')
HYP_df.head()
# Out:
#         SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  DIABETES  \
# RANDID
# 2448      1    195.0   39  106.0   70.0         0      0.0  26.97         0
# 6238      2    250.0   46  121.0   81.0         0      0.0  28.73         0
# 9428      1    245.0   48  127.5   80.0         1     20.0  25.34         0
# 11252     2    285.0   46  130.0   84.0         1     23.0  23.10         0
# 12629     2    205.0   63  138.0   71.0         0      0.0  33.11         0
#
#         BPMEDS   ...     GLUCOSE  PREVCHD  PREVAP  PREVSTRK  PREVHYP  TIME  \
# RANDID           ...
# 2448       0.0   ...        77.0        0       0         0        0     0
# 6238       0.0   ...        76.0        0       0         0        0     0
# 9428       0.0   ...        70.0        0       0         0        0     0
# 11252      0.0   ...        85.0        0       0         0        0     0
# 12629      0.0   ...        85.0        0       0         0        0     0
#
#         PERIOD  DEATH  HYPERTEN  TIMEHYP
# RANDID
# 2448         1      0         0     8766
# 6238         1      0         0     8766
# 9428         1      0         0     8766
# 11252        1      0         1     4285
# 12629        1      0         1     2212
#
# [5 rows x 21 columns]

# %%
#Number of events for Hypertension calls and number of non-events
HYP_count = HYP_df.loc[(HYP_df['HYPERTEN']==1)]
no_event_count = HYP_df.loc[(HYP_df['HYPERTEN']==0)]

print(f'Subjects afflcited with HYP: {len(HYP_count)}')
print(f'Subjects with no HYP events: {len(no_event_count)}')
# Out:
# Subjects afflcited with HYP: 1608
# Subjects with no HYP events: 1046

# %%
HYP_df.columns
# Out:
# Index(['SEX', 'TOTCHOL', 'AGE', 'SYSBP', 'DIABP', 'CURSMOKE', 'CIGPDAY', 'BMI',
#        'DIABETES', 'BPMEDS', 'HEARTRTE', 'GLUCOSE', 'PREVCHD', 'PREVAP',
#        'PREVSTRK', 'PREVHYP', 'TIME', 'PERIOD', 'DEATH', 'HYPERTEN',
#        'TIMEHYP'],
#       dtype='object')

# %%
HYP_reg_df = HYP_df[['SEX', 'TOTCHOL', 'AGE', 'SYSBP', 'DIABP', 'CURSMOKE', 'CIGPDAY', 'BMI',
                    'DIABETES', 'BPMEDS', 'HEARTRTE', 'GLUCOSE', 'PREVCHD', 'PREVAP', 
                    'PREVMI', 'PREVSTRK', 'PREVHYP', 'HYPERTEN']]
HYP_reg_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-41e1e3cba816> in <module>
#       1 HYP_reg_df = HYP_df[['SEX', 'TOTCHOL', 'AGE', 'SYSBP', 'DIABP', 'CURSMOKE', 'CIGPDAY', 'BMI',
#       2                     'DIABETES', 'BPMEDS', 'HEARTRTE', 'GLUCOSE', 'PREVCHD', 'PREVAP',
# ----> 3                     'PREVMI', 'PREVSTRK', 'PREVHYP', 'HYPERTEN']]
#       4 HYP_reg_df.head()
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['PREVMI'] not in index"
