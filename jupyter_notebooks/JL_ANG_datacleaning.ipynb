# %%
import pandas as pd

# %%
df = pd.read_csv('../Resources/frmgham2.csv')
df.head()
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1    2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 2    6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 3    6238    2    260.0   52  105.0   69.5         0      0.0  29.43
# 4    6238    2    237.0   58  108.0   66.0         0      0.0  28.50
#
#    DIABETES   ...     CVD  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  \
# 0         0   ...       1         0    8766    6438      6438     6438
# 1         0   ...       1         0    8766    6438      6438     6438
# 2         0   ...       0         0    8766    8766      8766     8766
# 3         0   ...       0         0    8766    8766      8766     8766
# 4         0   ...       0         0    8766    8766      8766     8766
#
#    TIMESTRK  TIMECVD  TIMEDTH  TIMEHYP
# 0      8766     6438     8766     8766
# 1      8766     6438     8766     8766
# ...

# %%
df.columns
# Out:
# Index(['RANDID', 'SEX', 'TOTCHOL', 'AGE', 'SYSBP', 'DIABP', 'CURSMOKE',
#        'CIGPDAY', 'BMI', 'DIABETES', 'BPMEDS', 'HEARTRTE', 'GLUCOSE', 'educ',
#        'PREVCHD', 'PREVAP', 'PREVMI', 'PREVSTRK', 'PREVHYP', 'TIME', 'PERIOD',
#        'HDLC', 'LDLC', 'DEATH', 'ANGINA', 'HOSPMI', 'MI_FCHD', 'ANYCHD',
#        'STROKE', 'CVD', 'HYPERTEN', 'TIMEAP', 'TIMEMI', 'TIMEMIFC', 'TIMECHD',
#        'TIMESTRK', 'TIMECVD', 'TIMEDTH', 'TIMEHYP'],
#       dtype='object')

# %%
ANG_df = df.loc[(df['PERIOD']==1) & (df['ANGINA']==0)]
ANG_df
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0         2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 2         6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 5         9428    1    245.0   48  127.5   80.0         1     20.0  25.34
# 7        10552    2    225.0   61  150.0   95.0         1     30.0  28.58
# 9        11252    2    285.0   46  130.0   84.0         1     23.0  23.10
# 12       11263    2    228.0   43  180.0  110.0         0      0.0  30.30
# 17       12806    2    313.0   45  100.0   71.0         1     20.0  21.68
# 20       14367    1    260.0   52  141.5   89.0         0      0.0  26.36
# 23       16365    1    225.0   43  162.0  107.0         1     30.0  23.61
# 26       16799    2    254.0   50  133.0   76.0         0      0.0  22.91
# 29       19304    2    247.0   43  131.0   88.0         0      0.0  27.64
# 30       20375    1    294.0   46  142.0   94.0         1     15.0  26.31
# ...

# %%
ANG_columns = ['RANDID', 'SEX', 'TOTCHOL', 'AGE', 'SYSBP', 'DIABP', 'CURSMOKE', 'CIGPDAY', 'BMI', 'DIABETES', 'BPMEDS',
              'HEARTRTE', 'GLUCOSE', 'PREVMI', 'PREVCHD', 'PREVAP', 'PREVSTRK', 'PREVHYP', 'TIME', 'PERIOD', 'DEATH', 'ANGINA',
              'TIMEAP']
ANG_df = ANG_df[ANG_columns]
ANG_df
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0         2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 2         6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 5         9428    1    245.0   48  127.5   80.0         1     20.0  25.34
# 7        10552    2    225.0   61  150.0   95.0         1     30.0  28.58
# 9        11252    2    285.0   46  130.0   84.0         1     23.0  23.10
# 12       11263    2    228.0   43  180.0  110.0         0      0.0  30.30
# 17       12806    2    313.0   45  100.0   71.0         1     20.0  21.68
# 20       14367    1    260.0   52  141.5   89.0         0      0.0  26.36
# 23       16365    1    225.0   43  162.0  107.0         1     30.0  23.61
# 26       16799    2    254.0   50  133.0   76.0         0      0.0  22.91
# 29       19304    2    247.0   43  131.0   88.0         0      0.0  27.64
# 30       20375    1    294.0   46  142.0   94.0         1     15.0  26.31
# ...

# %%
ANG_df.isnull().sum()
# Out:
# RANDID        0
# SEX           0
# TOTCHOL      45
# AGE           0
# SYSBP         0
# DIABP         0
# CURSMOKE      0
# CIGPDAY      24
# BMI          18
# DIABETES      0
# BPMEDS       41
# HEARTRTE      1
# GLUCOSE     342
# PREVMI        0
# PREVCHD       0
# PREVAP        0
# PREVSTRK      0
# PREVHYP       0
# TIME          0
# PERIOD        0
# DEATH         0
# ANGINA        0
# TIMEAP        0
# dtype: int64

# %%
ANG_final_df = ANG_df.dropna()
ANG_final_df
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0         2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 2         6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 5         9428    1    245.0   48  127.5   80.0         1     20.0  25.34
# 7        10552    2    225.0   61  150.0   95.0         1     30.0  28.58
# 9        11252    2    285.0   46  130.0   84.0         1     23.0  23.10
# 12       11263    2    228.0   43  180.0  110.0         0      0.0  30.30
# 17       12806    2    313.0   45  100.0   71.0         1     20.0  21.68
# 20       14367    1    260.0   52  141.5   89.0         0      0.0  26.36
# 23       16365    1    225.0   43  162.0  107.0         1     30.0  23.61
# 26       16799    2    254.0   50  133.0   76.0         0      0.0  22.91
# 29       19304    2    247.0   43  131.0   88.0         0      0.0  27.64
# 30       20375    1    294.0   46  142.0   94.0         1     15.0  26.31
# ...

# %%
ANG_final_df = ANG_df.dropna()
ANG_final_df
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0         2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 2         6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 5         9428    1    245.0   48  127.5   80.0         1     20.0  25.34
# 7        10552    2    225.0   61  150.0   95.0         1     30.0  28.58
# 9        11252    2    285.0   46  130.0   84.0         1     23.0  23.10
# 12       11263    2    228.0   43  180.0  110.0         0      0.0  30.30
# 17       12806    2    313.0   45  100.0   71.0         1     20.0  21.68
# 20       14367    1    260.0   52  141.5   89.0         0      0.0  26.36
# 23       16365    1    225.0   43  162.0  107.0         1     30.0  23.61
# 26       16799    2    254.0   50  133.0   76.0         0      0.0  22.91
# 29       19304    2    247.0   43  131.0   88.0         0      0.0  27.64
# 30       20375    1    294.0   46  142.0   94.0         1     15.0  26.31
# ...

# %%
ANG_final_df.isnull().sum()
# Out:
# RANDID      0
# SEX         0
# TOTCHOL     0
# AGE         0
# SYSBP       0
# DIABP       0
# CURSMOKE    0
# CIGPDAY     0
# BMI         0
# DIABETES    0
# BPMEDS      0
# HEARTRTE    0
# GLUCOSE     0
# PREVMI      0
# PREVCHD     0
# PREVAP      0
# PREVSTRK    0
# PREVHYP     0
# TIME        0
# PERIOD      0
# DEATH       0
# ANGINA      0
# TIMEAP      0
# dtype: int64

# %%
ANG_final_df.to_csv('../Resources/ANG_final_data.csv', index=False)

# %%
ANG_g_df = ANG_df.drop(columns=['GLUCOSE'])
ANG_g_final_df = ANG_g_df.dropna()
ANG_g_final_df
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0         2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 2         6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 5         9428    1    245.0   48  127.5   80.0         1     20.0  25.34
# 7        10552    2    225.0   61  150.0   95.0         1     30.0  28.58
# 9        11252    2    285.0   46  130.0   84.0         1     23.0  23.10
# 12       11263    2    228.0   43  180.0  110.0         0      0.0  30.30
# 17       12806    2    313.0   45  100.0   71.0         1     20.0  21.68
# 20       14367    1    260.0   52  141.5   89.0         0      0.0  26.36
# 23       16365    1    225.0   43  162.0  107.0         1     30.0  23.61
# 26       16799    2    254.0   50  133.0   76.0         0      0.0  22.91
# 29       19304    2    247.0   43  131.0   88.0         0      0.0  27.64
# 30       20375    1    294.0   46  142.0   94.0         1     15.0  26.31
# ...

# %%
ANG_g_final_df.isnull().sum()
# Out:
# RANDID      0
# SEX         0
# TOTCHOL     0
# AGE         0
# SYSBP       0
# DIABP       0
# CURSMOKE    0
# CIGPDAY     0
# BMI         0
# DIABETES    0
# BPMEDS      0
# HEARTRTE    0
# PREVMI      0
# PREVCHD     0
# PREVAP      0
# PREVSTRK    0
# PREVHYP     0
# TIME        0
# PERIOD      0
# DEATH       0
# ANGINA      0
# TIMEAP      0
# dtype: int64

# %%
ANG_g_final_df.to_csv('../Resources/ANG_final_noglucose.csv', index=False)

# %%
ANG_3_df = df.loc[(df['PERIOD']==3) & (df['ANGINA']==0)]
ANG_3_df
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 1         2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 4         6238    2    237.0   58  108.0   66.0         0      0.0  28.50
# 11       11252    2      NaN   58  155.0   90.0         1     30.0  24.61
# 14       11263    2    220.0   55  180.0  106.0         0      0.0  31.17
# 19       12806    2    320.0   57  110.0   46.0         1     30.0  22.02
# 22       14367    1    280.0   64  168.0  100.0         0      0.0  25.72
# 25       16365    1    211.0   55  173.0  123.0         0      0.0  29.11
# 28       16799    2    291.0   62  120.0   70.0         0      0.0  21.98
# 34       23727    2    159.0   53  124.0   78.0         0      0.0  26.62
# 37       24721    2    264.0   51  141.0   81.0         1     15.0  24.77
# 41       33077    1    215.0   60  144.5   80.0         1     10.0  22.96
# 45       34689    2    212.0   49  163.0   96.0         1     10.0  31.45
# ...

# %%
ANG_3_df.isnull().sum()
# Out:
# RANDID        0
# SEX           0
# TOTCHOL     180
# AGE           0
# SYSBP         0
# DIABP         0
# CURSMOKE      0
# CIGPDAY      11
# BMI          14
# DIABETES      0
# BPMEDS      387
# HEARTRTE      3
# GLUCOSE     469
# educ         68
# PREVCHD       0
# PREVAP        0
# PREVMI        0
# PREVSTRK      0
# PREVHYP       0
# TIME          0
# PERIOD        0
# HDLC        200
# LDLC        201
# DEATH         0
# ANGINA        0
# HOSPMI        0
# MI_FCHD       0
# ANYCHD        0
# STROKE        0
# CVD           0
# HYPERTEN      0
# TIMEAP        0
# TIMEMI        0
# TIMEMIFC      0
# TIMECHD       0
# TIMESTRK      0
# TIMECVD       0
# TIMEDTH       0
# TIMEHYP       0
# dtype: int64

# %%
ANG_3_columns = ['RANDID', 'SEX', 'TOTCHOL', 'AGE', 'SYSBP', 'DIABP', 'CURSMOKE', 'CIGPDAY', 'BMI', 'DIABETES', 'BPMEDS',
              'HEARTRTE', 'GLUCOSE', 'PREVCHD', 'PREVAP', 'PREVSTRK', 'PREVHYP', 'TIME', 'PERIOD', 'DEATH', 'HDLC', 'LDLC', 'ANGINA',
              'TIMEAP']
ANG_3_df = ANG_3_df[ANG_3_columns]
ANG_3_df_final = ANG_3_df.dropna()
ANG_3_df_final
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 4         6238    2    237.0   58  108.0   66.0         0      0.0  28.50
# 14       11263    2    220.0   55  180.0  106.0         0      0.0  31.17
# 19       12806    2    320.0   57  110.0   46.0         1     30.0  22.02
# 22       14367    1    280.0   64  168.0  100.0         0      0.0  25.72
# 25       16365    1    211.0   55  173.0  123.0         0      0.0  29.11
# 34       23727    2    159.0   53  124.0   78.0         0      0.0  26.62
# 37       24721    2    264.0   51  141.0   81.0         1     15.0  24.77
# 41       33077    1    215.0   60  144.5   80.0         1     10.0  22.96
# 45       34689    2    212.0   49  163.0   96.0         1     10.0  31.45
# 48       36459    1    162.0   53  152.5  101.0         0      0.0  26.43
# 51       40435    2    226.0   54  126.0   75.0         1     40.0  21.59
# 57       43770    2    283.0   64  159.0   69.0         0      0.0  32.93
# ...

# %%
ANG_3_df_final.isnull().sum()
# Out:
# RANDID      0
# SEX         0
# TOTCHOL     0
# AGE         0
# SYSBP       0
# DIABP       0
# CURSMOKE    0
# CIGPDAY     0
# BMI         0
# DIABETES    0
# BPMEDS      0
# HEARTRTE    0
# GLUCOSE     0
# PREVCHD     0
# PREVAP      0
# PREVSTRK    0
# PREVHYP     0
# TIME        0
# PERIOD      0
# DEATH       0
# HDLC        0
# LDLC        0
# ANGINA      0
# TIMEAP      0
# dtype: int64

# %%
ANG_3_df_final.to_csv('../Resources/ANG_period3_data.csv', index=False)
