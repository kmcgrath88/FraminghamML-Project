# %% [markdown]
# STROKE_SVM

# %%
#import dependencies
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("STROKE_final_data.csv")
df.head(20)
# Out:
#     RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0     2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1     6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 2     9428    1    245.0   48  127.5   80.0         1     20.0  25.34
# 3    10552    2    225.0   61  150.0   95.0         1     30.0  28.58
# 4    11252    2    285.0   46  130.0   84.0         1     23.0  23.10
# 5    11263    2    228.0   43  180.0  110.0         0      0.0  30.30
# 6    12629    2    205.0   63  138.0   71.0         0      0.0  33.11
# 7    12806    2    313.0   45  100.0   71.0         1     20.0  21.68
# 8    14367    1    260.0   52  141.5   89.0         0      0.0  26.36
# 9    16365    1    225.0   43  162.0  107.0         1     30.0  23.61
# 10   16799    2    254.0   50  133.0   76.0         0      0.0  22.91
# 11   19304    2    247.0   43  131.0   88.0         0      0.0  27.64
# 12   20375    1    294.0   46  142.0   94.0         1     15.0  26.31
# 13   23727    2    332.0   41  124.0   88.0         0      0.0  31.31
# 14   30928    2    221.0   38  140.0   90.0         1     20.0  21.35
# 15   33077    1    232.0   48  138.0   90.0         1     10.0  22.37
# 16   33555    2    291.0   46  112.0   78.0         1     20.0  23.38
# 17   34689    2    195.0   38  122.0   84.5         1      5.0  23.24
# 18   36459    1    195.0   41  139.0   88.0         0      0.0  26.88
# 19   40435    2    190.0   42  108.0   70.5         1     30.0  21.59
#
#     DIABETES  ...  GLUCOSE  PREVCHD  PREVAP  PREVMI  PREVSTRK  PREVHYP  TIME  \
# 0          0  ...     77.0        0       0       0         0        0     0
# 1          0  ...     76.0        0       0       0         0        0     0
# 2          0  ...     70.0        0       0       0         0        0     0
# 3          0  ...    103.0        0       0       0         0        1     0
# 4          0  ...     85.0        0       0       0         0        0     0
# 5          0  ...     99.0        0       0       0         0        1     0
# 6          0  ...     85.0        0       0       0         0        0     0
# 7          0  ...     78.0        0       0       0         0        0     0
# 8          0  ...     79.0        0       0       0         0        1     0
# 9          0  ...     88.0        0       0       0         0        1     0
# 10         0  ...     76.0        0       0       0         0        0     0
# 11         0  ...     61.0        0       0       0         0        0     0
# 12         0  ...     64.0        0       0       0         0        1     0
# 13         0  ...     84.0        0       0       0         0        1     0
# 14         0  ...     70.0        0       0       0         0        1     0
# 15         0  ...     72.0        0       0       0         0        1     0
# 16         0  ...     89.0        0       0       0         0        0     0
# 17         0  ...     78.0        0       0       0         0        0     0
# 18         0  ...     65.0        0       0       0         0        0     0
# 19         0  ...     85.0        0       0       0         0        0     0
#
#     PERIOD  DEATH  STROKE
# 0        1      0       0
# 1        1      0       0
# 2        1      0       0
# 3        1      1       1
# 4        1      0       0
# 5        1      0       0
# 6        1      0       0
# 7        1      0       0
# 8        1      0       0
# 9        1      0       0
# 10       1      0       0
# 11       1      0       0
# 12       1      0       0
# 13       1      1       0
# 14       1      1       0
# 15       1      0       0
# 16       1      1       0
# 17       1      0       0
# 18       1      0       0
# 19       1      0       0
#
# [20 rows x 22 columns]

# %%
STROKE_df = df.set_index('RANDID')
#Remove columns not involved in analysis
#removed 'Time', 'Period', 'Death', 'MI_FCHD', 'TIMEMI', 'TIMEMIFC'
STROKE_df = STROKE_df[['SEX', 'TOTCHOL', 'AGE', 'SYSBP', 'DIABP', 'CURSMOKE', 'CIGPDAY', 'BMI',
       'DIABETES', 'BPMEDS', 'HEARTRTE', 'GLUCOSE', 'PREVAP', 'PREVHYP', 'STROKE']]
STROKE_df.head()
# Out:
#         SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  DIABETES  \
# RANDID
# 2448      1    195.0   39  106.0   70.0         0      0.0  26.97         0
# 6238      2    250.0   46  121.0   81.0         0      0.0  28.73         0
# 9428      1    245.0   48  127.5   80.0         1     20.0  25.34         0
# 10552     2    225.0   61  150.0   95.0         1     30.0  28.58         0
# 11252     2    285.0   46  130.0   84.0         1     23.0  23.10         0
#
#         BPMEDS  HEARTRTE  GLUCOSE  PREVAP  PREVHYP  STROKE
# RANDID
# 2448       0.0      80.0     77.0       0        0       0
# 6238       0.0      95.0     76.0       0        0       0
# 9428       0.0      75.0     70.0       0        0       0
# 10552      0.0      65.0    103.0       0        1       1
# 11252      0.0      85.0     85.0       0        0       0

# %%
target = STROKE_df["STROKE"]
target_names = ["negative", "positive"]

# %%
data = STROKE_df.drop("STROKE", axis=1)
feature_names = data.columns
data.head()
# Out:
#         SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  DIABETES  \
# RANDID
# 2448      1    195.0   39  106.0   70.0         0      0.0  26.97         0
# 6238      2    250.0   46  121.0   81.0         0      0.0  28.73         0
# 9428      1    245.0   48  127.5   80.0         1     20.0  25.34         0
# 10552     2    225.0   61  150.0   95.0         1     30.0  28.58         0
# 11252     2    285.0   46  130.0   84.0         1     23.0  23.10         0
#
#         BPMEDS  HEARTRTE  GLUCOSE  PREVAP  PREVHYP
# RANDID
# 2448       0.0      80.0     77.0       0        0
# 6238       0.0      95.0     76.0       0        0
# 9428       0.0      75.0     70.0       0        0
# 10552      0.0      65.0    103.0       0        1
# 11252      0.0      85.0     85.0       0        0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=49)

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')

# %%
# Create the GridSearch estimator along with a parameter object containing the values to adjust
# Adjust `C` with values of 1, 5, and 10. Adjust `gamma` using .0001, 0.001, and 0.01
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Fit the model using the grid search estimator. 
# This will take the SVC model and try each combination of parameters
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................... C=1, gamma=0.0001, score=0.915, total=  32.4s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   32.4s remaining:    0.0s
# [CV] ................... C=1, gamma=0.0001, score=0.915, total=  32.4s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.1min remaining:    0.0s
# [CV] ................... C=1, gamma=0.0001, score=0.915, total=  30.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.913, total=  32.5s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.913, total=  31.6s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.915, total=  31.9s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.915, total=  31.1s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.915, total=  28.3s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.913, total=  31.9s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.913, total=  31.6s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.915, total=  31.8s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.915, total=  32.1s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.915, total=  29.9s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.913, total=  32.7s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.913, total=  31.6s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.915, total=  42.5s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.915, total=  51.3s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.915, total=  48.3s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.913, total=  34.3s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.913, total=  38.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.915, total=  43.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.915, total=  52.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.915, total=  48.6s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.913, total=  33.9s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.913, total=  37.3s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.915, total=  43.9s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.915, total=  51.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.915, total=  48.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.913, total=  39.3s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.913, total=  44.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.915, total= 1.3min
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.913, total= 1.1min
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.915, total=  57.8s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.913, total= 1.1min
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.913, total= 1.1min
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.915, total= 1.1min
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.913, total= 1.1min
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.915, total=  53.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.913, total=  59.5s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.913, total=  53.2s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.915, total=  57.3s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.913, total=  52.4s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.915, total=  48.1s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.913, total=  56.4s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.913, total=  53.7s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 33.8min finished
# GridSearchCV(estimator=SVC(kernel='linear'),
#              param_grid={'C': [1, 5, 10], 'gamma': [0.0001, 0.001, 0.01]},
#              verbose=3)

# %%
# List the best parameters for this dataset
print(grid.best_params_)
# Out:
# {'C': 1, 'gamma': 0.0001}

# %%
# List the best score
print(grid.best_score_)
# Out:
# 0.9138461538461538

# %%
# Make predictions with the hypertuned model
predictions = grid.predict(X_test)

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.91      1.00      0.95       884
#     positive       0.00      0.00      0.00        92
#
#     accuracy                           0.91       976
#    macro avg       0.45      0.50      0.48       976
# weighted avg       0.82      0.91      0.86       976
# /Users/bhuffstetler/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
STROKE_predictions = pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
STROKE_predictions
# Out:
#      Prediction  Actual
# 0             0       0
# 1             0       1
# 2             0       0
# 3             0       0
# 4             0       0
# ..          ...     ...
# 971           0       0
# 972           0       0
# 973           0       0
# 974           0       0
# 975           0       1
#
# [976 rows x 2 columns]

# %%
p0a0 = STROKE_predictions.loc[(STROKE_predictions['Prediction']==0) & (STROKE_predictions['Actual']==0)]
p1a1 = STROKE_predictions.loc[(STROKE_predictions['Prediction']==1) & (STROKE_predictions['Actual']==1)]
p0a1 = STROKE_predictions.loc[(STROKE_predictions['Prediction']==0) & (STROKE_predictions['Actual']==1)]
p1a0 = STROKE_predictions.loc[(STROKE_predictions['Prediction']==1) & (STROKE_predictions['Actual']==0)]

print(f"Event prediction = 0 and actual = 0:  {len(p0a0)}")
print(f"Event prediction = 1 and actual = 1:  {len(p1a1)}")
print(f"Event prediction = 0 and actual = 1:  {len(p0a1)}")
print(f"Event prediction = 1 and actual = 0:  {len(p1a0)}")
# Out:
# Event prediction = 0 and actual = 0:  884
# Event prediction = 1 and actual = 1:  0
# Event prediction = 0 and actual = 1:  92
# Event prediction = 1 and actual = 0:  0
